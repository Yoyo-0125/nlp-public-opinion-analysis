# %%
from transformers import AutoModel, AutoTokenizer
import torch
import torch.nn.functional as F
import os

class ShortTopicDetect():
    def __init__(self, embed_model):
        super().__init__()
        self.embedding = AutoModel.from_pretrained(embed_model)
        self.tokenizer = AutoTokenizer.from_pretrained(embed_model)

    def forward(self, sentences):
        inputs = self.tokenizer(
            sentences,
            return_tensors='pt',
            padding=True,
            truncation=True,
            max_length=256
        )

        with torch.no_grad():
            outputs = self.embedding(**inputs)

        token_embed = outputs.last_hidden_state      # (Batch, T, H)
        attention_mask = inputs['attention_mask']    # (Batch, T)

        mask = attention_mask.unsqueeze(-1).expand(token_embed.size()).float()
        sentence_embed = (token_embed * mask).sum(dim=1) / mask.sum(dim=1)
        sentence_embed = F.normalize(sentence_embed, p=2, dim=1)

        return sentence_embed

model = ShortTopicDetect(embed_model=r'D:\Projects\nlp-public-opinion-analysis\src\models\text2vec-base-chinese')

# %%
from sentence_transformers import SentenceTransformer

import torch
import torch.nn.functional as F
import os

class ShortTopicDetect():
    def __init__(self, embed_model):
        super().__init__()
        self.embed_model = embed_model
        self.embedding = AutoModel.from_pretrained(embed_model)
        self.tokenizer = AutoTokenizer.from_pretrained(embed_model)

    def forward(self, sentences):
        model = SentenceTransformer(self.embed_model)
        embeddings = model.encode(sentences, normalize_embeddings=True)

        return embeddings

model = ShortTopicDetect(embed_model=r'D:\Projects\nlp-public-opinion-analysis\src\models\text2vec-base-chinese')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       3 import torch
#       4 import torch.nn.functional as F
#
# File d:\Programs\miniconda3\envs\py310\lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File d:\Programs\miniconda3\envs\py310\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File d:\Programs\miniconda3\envs\py310\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:21
#      19 from torch import nn
#      20 from tqdm.autonotebook import trange
# ---> 21 from transformers import (
#      22     AutoConfig,
#      23     AutoModelForSequenceClassification,
#      24     AutoTokenizer,
#      25     PretrainedConfig,
#      26     PreTrainedModel,
#      27     PreTrainedTokenizer,
#      28     is_torch_npu_available,
#      29 )
#      30 from transformers.utils import PushToHubMixin
#      31 from typing_extensions import deprecated
#
# ImportError: cannot import name 'PreTrainedModel' from 'transformers' (d:\Programs\miniconda3\envs\py310\lib\site-packages\transformers\__init__.py)

# %%
# Demo to test ShortTopicDetect class

sentences = ['今天的天气真好', '今天天气不错']
outputs = model.forward(sentences)
print('Embedding outputs:\n', outputs)
print('\n', outputs.shape)
print(outputs[0] @ outputs[1])  # Cosine similarity between two sentence embeddings
